# %%
#1.Identify and fix the syntax error in the following code:


age = 18
if age >= 18:
    print("You are eligible to vote")
# Out:
# You are eligible to vote

# %%
#2.Question:
What error will occur in the following code?


def greet():
    print("Hello, World!")

greet()
#Calling method name is wrong
# Out:
# Object `code` not found.
# Hello, World!

# %%
#3.Identify the error in this code:

name = "Alice"
age = 25
print("My name is " + name + " and I am " + str(age) + " years old.")
# Out:
# My name is Alice and I am 25 years old.

# %%
#4.Question:
#What will happen when you run this code?

a = 10
b = 0
result = a / b
print(result)
#Zero division error(10 whole number is not able to divide y 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 a = 10
#       5 b = 0
# ----> 6 result = a / b
#       7 print(result)
#       8 #Zero division error(10 whole number is not able to divide y 0)
#
# ZeroDivisionError: division by zero

# %%
#5.What error will occur in the following code?

num = int("xyz")
print(num)
#ValueError:xyz is string value.so that it's not able to convert integer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 #5.What error will occur in the following code?
# ----> 3 num = int("xyz")
#       4 print(num)
#       5 #ValueError:xyz is string value.so that it's not able to convert integer
#
# ValueError: invalid literal for int() with base 10: 'xyz'

# %%
#6.Identify the issue in this code:

data = {"name": "John", "age": 30,"city":"Chennai"}
print(data["city"])
# Out:
# Chennai

# %%
#7.What will happen when you run this code?
num = 6
while num < 5:
    print(num)
    
#This while runs always. because num<5 will be true for all the time

# %%
#8.What is wrong with this code?

fruits = ("apple", "banana", "cherry","orange")
print(fruits[3])
#3 rd index is not exist.So that we should change index value or add 3 rd index in this tuple
# Out:
# orange

# %%
#9.What will happen when you run this code?

text = "hello world"
#text.append("!")
print(text +"!")
#AttributeError: string has no attribute in the name of append.
# Out:
# hello world!

# %%
#10.What is wrong with the following code?

import randoms
print(randoms.randint(1, 10))
