# %%
#1
lists=[10,30,60,50,70]

lists.sort()
print(lists)
print("Second largest number in this list:" , lists[-2])
# Out:
# [10, 30, 50, 60, 70]
# Second largest number in this list: 60

# %%
#3
lists1=[1,3,5]
lists2=[2,4,6]
lists1.extend(lists2)

lists1.sort()
print(lists1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#4
nonRepeat={}
def NonRepreatChar(value):
    
    for x in value:
        if(x not in nonRepeat):
            nonRepeat[x]=1
    print(nonRepeat)        
   
NonRepreatChar("hello")
# Out:
# {'h': 1, 'e': 1, 'l': 1, 'o': 1}

# %%
#5
lists1=[1,2,3,4]
lists2=[5,6,2,7,3]
commonElements=[]
for x in lists1:
    if(x in lists2):
        commonElements.append(x)
    
print(commonElements)
# Out:
# [2, 3]

# %%
#6
def ReverseNumber(number:int):
    stringValue=str(number)
    print(stringValue[::-1])
ReverseNumber(12345)
# Out:
# 54321

# %%
#7
sentence="Hi Hello Welcome!"
words=sentence.split()
print(words)
wordCount=len(words)
print(wordCount)
# Out:
# ['Hi', 'Hello', 'Welcome!']
# 3

# %%
#8
def Factorial():
    result=1
    for n in range(1,6):
        result=result*n
    return result
Factorial()
# Out:
# 120

# %%
#9
stringList=['hi','hello','welcome']
upperCase=[]
for x in stringList:
    upperCase.append(x.upper())
print(upperCase)
# Out:
# ['HI', 'HELLO', 'WELCOME']
