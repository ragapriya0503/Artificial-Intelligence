# %%
import pickle
load_model=pickle.load(open("LinearRegression_finalModel.sav",'rb'))
inputvalue=int(input("Enter the Experience"))
result=load_model.predict([[inputvalue]])
# Out:
# Enter the Experience 13
# C:\Users\ragap\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
