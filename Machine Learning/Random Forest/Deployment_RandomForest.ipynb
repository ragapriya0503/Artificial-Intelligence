# %%
import pickle
filename="randomforest_finalmodel.sav"
model=pickle.load(open(filename,"rb"))
rd_input=float(input("R&D:"))
admin_input=float(input("Admin"))
marketing_input=float(input("Marketing "))
florida_input=int(input("State_flo 0 or 1:"))
newyork_input=int(input("State_new 0 or 1:"))
# Out:
# R&D: 100671.96
# Admin 91790.61
# Marketing  249744.55
# State_flo 0 or 1: 0
# State_new 0 or 1: 0

# %%
result=model.predict([[rd_input,admin_input,marketing_input,florida_input,newyork_input]])
result
# Out:
# C:\Users\ragap\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([134767.7027])
