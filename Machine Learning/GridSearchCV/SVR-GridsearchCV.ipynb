# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independant=dataset[["age","bmi","children","sex_male","smoker_yes"]]
dependant=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independant,dependant,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
X_train=std.fit_transform(X_train)
X_test=std.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['rbf','poly','sigmoid','linear'],'C':[10,100,1000,2000],'gamma':['auto','scale']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\ragap\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000], 'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
result=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.044297      0.003658         0.020079        0.001572       10
# 1        0.037361      0.002158         0.007502        0.000640       10
# 2        0.046132      0.003380         0.009842        0.000870       10
# 3        0.033408      0.002554         0.007801        0.000785       10
# 4        0.043186      0.002435         0.021683        0.000512       10
# 5        0.036659      0.001742         0.007955        0.000228       10
# 6        0.046559      0.001313         0.009901        0.000419       10
# 7        0.038805      0.002594         0.007556        0.000440       10
# 8        0.042937      0.001608         0.021475        0.000888      100
# 9        0.040912      0.003150         0.007906        0.000101      100
# 10       0.048955      0.000293         0.009979        0.000201      100
# 11       0.044797      0.001119         0.007662        0.000217      100
# 12       0.044876      0.002332         0.021604        0.000236      100
# 13       0.040213      0.001751         0.008109        0.000363      100
# 14       0.048385      0.002322         0.009872        0.000176      100
# 15       0.046222      0.002492         0.008316        0.000878      100
# 16       0.056739      0.003674         0.022026        0.000549     1000
# 17       0.055378      0.007998         0.008093        0.000327     1000
# 18       0.052910      0.003919         0.009805        0.000095     1000
# 19       0.052272      0.004734         0.008198        0.000876     1000
# 20       0.054309      0.002498         0.021572        0.000861     1000
# 21       0.059061      0.012259         0.007890        0.000095     1000
# 22       0.052082      0.001906         0.010332        0.000871     1000
# 23       0.051011      0.003157         0.007621        0.000113     1000
# 24       0.058030      0.003205         0.022954        0.001571     2000
# 25       0.094073      0.017107         0.008210        0.000549     2000
# 26       0.056804      0.003551         0.009926        0.000168     2000
# 27       0.063228      0.007998         0.007836        0.000435     2000
# 28       0.056013      0.001723         0.021539        0.000266     2000
# 29       0.086283      0.005293         0.007396        0.002289     2000
# 30       0.054904      0.003099         0.010502        0.000861     2000
# 31       0.045560      0.011797         0.004963        0.001446     2000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.049905
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.377969
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.049644
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.377969
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.733044
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.829631
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.296082
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.605304
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733334
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.828213
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.400044
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.605304
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.814076
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.845403
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.401855
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.605277
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.814295
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.845581
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.385658
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.605277
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.013366          -0.103821          -0.095119
# 1            0.069532          -0.045601          -0.025079
# 2            0.075905          -0.046585          -0.041004
# 3            0.479601           0.317872           0.337979
# 4            0.013244          -0.103775          -0.095165
# 5            0.071297          -0.046513          -0.024157
# 6            0.076323          -0.046798          -0.040824
# 7            0.479601           0.317872           0.337979
# 8            0.339474           0.173708           0.217991
# 9            0.575051           0.474839           0.535730
# 10           0.561673           0.428331           0.450454
# 11           0.655818           0.553380           0.576939
# 12           0.338741           0.174086           0.217641
# 13           0.579373           0.471840           0.537966
# 14           0.563200           0.427152           0.451250
# 15           0.655818           0.553380           0.576939
# 16           0.746232           0.686773           0.717920
# 17           0.802622           0.799620           0.800321
# 18           0.372281           0.216401           0.291265
# 19           0.588725           0.623230           0.537931
# 20           0.745892           0.687037           0.717769
# 21           0.802622           0.799348           0.800587
# 22           0.366097           0.242217           0.288461
# 23           0.588725           0.623230           0.537931
# 24           0.781092           0.794081           0.794075
# 25           0.805639           0.816733           0.805143
# 26          -0.508082          -0.452827          -0.751013
# 27           0.583646           0.697368           0.532547
# 28           0.780971           0.794227           0.793983
# 29           0.805624           0.816612           0.805133
# 30          -0.537098          -0.474912          -0.477335
# 31           0.583646           0.697368           0.532547
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.101604        -0.056625        0.053504               29
# 1           -0.049592         0.001107        0.051309               26
# 2           -0.046507        -0.001657        0.053391               28
# 3            0.324422         0.367569        0.059777               19
# 4           -0.101602        -0.056634        0.053486               30
# 5           -0.049652         0.001188        0.051594               25
# 6           -0.046521        -0.001635        0.053474               27
# 7            0.324422         0.367569        0.059777               19
# 8            0.183375         0.243024        0.065733               23
# 9            0.424640         0.510181        0.053582               15
# 10           0.431701         0.470105        0.049110               18
# 11           0.546881         0.583498        0.038787               13
# 12           0.183403         0.242982        0.065542               24
# 13           0.424478         0.510155        0.054955               16
# 14           0.432199         0.470546        0.049762               17
# 15           0.546881         0.583498        0.038787               13
# 16           0.649158         0.706625        0.034902                8
# 17           0.735580         0.793555        0.031072                3
# 18           0.351325         0.305471        0.054387               22
# 19           0.616726         0.594383        0.030560               11
# 20           0.649174         0.706641        0.034825                7
# 21           0.735555         0.793265        0.030757                4
# 22           0.351407         0.329645        0.056742               21
# 23           0.616726         0.594383        0.030560               11
# 24           0.733656         0.783396        0.027014                6
# 25           0.754961         0.805576        0.029233                2
# 26          -0.111859        -0.445127        0.205197               32
# 27           0.681425         0.620053        0.061555                9
# 28           0.733663         0.783428        0.027068                5
# 29           0.754962         0.805582        0.029272                1
# 30          -0.111187        -0.397238        0.150976               31
# 31           0.681425         0.620053        0.061555                9

# %%
age=float(input("Age"))
bmi=float(input("BMI"))
child=float(input("Children"))
male=float(input("Male or Female ( 0 or 1)"))
smoke=float(input("Smoker yes or no ( 0 or 1)"))
# Out:
# Age 19
# BMI 0
# Children 0
# Male or Female ( 0 or 1) 1
# Smoker yes or no ( 0 or 1) 0

# %%
future_prediction=grid.predict([[age,bmi,child,male,smoke]])

# %%
future_prediction
# Out:
# array([1888571.36590982])
