# %%
import pandas as pd
dt=pd.read_csv('C:\AI\Artificial-Intelligence\Machine Learning\Classification\Social_Network_Ads.csv')
dt
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dt=pd.get_dummies(dt,dtype=int,drop_first=True)
dt
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dt=dt.drop('User ID',axis=1)
dt
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
ip=dt[['Age','EstimatedSalary','Gender_Male']]
op=dt['Purchased']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'C':[10,100,1000],'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'gamma':['scale','auto']}
grid_model=GridSearchCV(SVC(probability=True),param_grid,refit=True,verbose=3,cv=5,n_jobs=-1,scoring='f1_weighted')
grid_model.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
result=grid_model.cv_results_

# %%
grid_pred=grid_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_pred)
print(cm)
# Out:
# [[73  6]
#  [ 4 37]]

# %%
from sklearn.metrics import classification_report
classy=classification_report(y_test,grid_pred)
print(classy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        79
#            1       0.86      0.90      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.90      0.91      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
from sklearn.metrics import roc_auc_score # r-receiver, o-operating, c- curve | a-area, u- under, c-curve
roc_auc_score(y_test,grid_model.predict_proba(x_test)[:,1])
# Out:
# np.float64(0.9654214263661625)

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.018032      0.001081         0.007179        0.000319       10
# 1        0.019409      0.003982         0.007588        0.000955       10
# 2        0.014291      0.002648         0.006302        0.000785       10
# 3        0.011958      0.001453         0.005917        0.000976       10
# 4        0.017122      0.002039         0.005864        0.000421       10
# 5        0.016403      0.002164         0.005906        0.001095       10
# 6        0.014166      0.001880         0.006792        0.001554       10
# 7        0.011996      0.002139         0.006385        0.001378       10
# 8        0.052133      0.008485         0.005026        0.000249      100
# 9        0.061198      0.009957         0.005335        0.000817      100
# 10       0.018491      0.002184         0.006664        0.001951      100
# 11       0.009946      0.000247         0.005398        0.000731      100
# 12       0.050386      0.004759         0.004831        0.000348      100
# 13       0.058179      0.010845         0.005309        0.000549      100
# 14       0.018521      0.002361         0.005275        0.000251      100
# 15       0.009653      0.000595         0.004611        0.000229      100
# 16       0.336600      0.083611         0.004266        0.000432     1000
# 17       0.423870      0.121662         0.004363        0.000420     1000
# 18       0.055612      0.007862         0.005389        0.000651     1000
# 19       0.010159      0.000403         0.004600        0.000394     1000
# 20       0.308038      0.058755         0.004551        0.000080     1000
# 21       0.431066      0.140117         0.003845        0.000548     1000
# 22       0.051607      0.007032         0.005225        0.000562     1000
# 23       0.010507      0.000619         0.004508        0.000438     1000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 1       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 2        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.892857
# 3    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.769053
# 4      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 5        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 6         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.892857
# 7     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 8    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 9      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 10      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.855314
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.769053
# 12    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 13      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 14       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.855314
# 15   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 16  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 17    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 18     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.835985
# 19  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.769053
# 20   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 21     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 22      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.835985
# 23  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.782971           0.644599           0.927778
# 1            0.799537           0.737557           0.928571
# 2            0.875644           0.841398           0.947015
# 3            0.733523           0.610390           0.753871
# 4            0.782971           0.644599           0.927778
# 5            0.799537           0.737557           0.928571
# 6            0.875644           0.841398           0.947015
# 7            0.733523           0.730543           0.753871
# 8            0.782971           0.644599           0.927778
# 9            0.799537           0.737557           0.928571
# 10           0.892857           0.859435           0.929144
# 11           0.714286           0.750000           0.753871
# 12           0.782971           0.644599           0.927778
# 13           0.799537           0.715601           0.928571
# 14           0.892857           0.859435           0.929144
# 15           0.714286           0.750000           0.686036
# 16           0.782971           0.644599           0.927778
# 17           0.799537           0.715601           0.928571
# 18           0.875644           0.858503           0.911105
# 19           0.714286           0.750000           0.694864
# 20           0.782971           0.644599           0.927778
# 21           0.799537           0.715601           0.928571
# 22           0.875644           0.858503           0.911105
# 23           0.714286           0.750000           0.694864
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.890114         0.816289        0.098849               13
# 1            0.888158         0.837369        0.066798                8
# 2            0.946153         0.900613        0.041029                1
# 3            0.759910         0.725349        0.058652               24
# 4            0.890114         0.816289        0.098849               13
# 5            0.888158         0.837369        0.066798                8
# 6            0.946153         0.900613        0.041029                1
# 7            0.759910         0.749380        0.014996               20
# 8            0.890114         0.816289        0.098849               13
# 9            0.907658         0.841269        0.070136                7
# 10           0.928571         0.893064        0.031996                3
# 11           0.759910         0.749424        0.018709               19
# 12           0.890114         0.816289        0.098849               13
# 13           0.907658         0.836878        0.076857               10
# 14           0.928571         0.893064        0.031996                3
# 15           0.759910         0.735857        0.031074               23
# 16           0.890114         0.816289        0.098849               13
# 17           0.907658         0.836878        0.076857               10
# 18           0.890114         0.874270        0.025784                5
# 19           0.759910         0.737623        0.028322               21
# 20           0.890114         0.816289        0.098849               13
# 21           0.907658         0.836878        0.076857               10
# 22           0.890114         0.874270        0.025784                5
# 23           0.759910         0.737623        0.028322               21
