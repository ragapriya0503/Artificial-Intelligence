# %%
import pandas as pd

# %%
dt=pd.read_csv('C:\AI\Artificial-Intelligence\Machine Learning\Classification\Social_Network_Ads.csv')
dt
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dt=pd.get_dummies(dt,dtype=int,drop_first=True)
dt
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dt=dt.drop('User ID',axis=1)
dt
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
ip=dt[['Age','EstimatedSalary','Gender_Male']]
op=dt['Purchased']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],'penalty':['l1', 'l2', 'elasticnet']}
grid_model=GridSearchCV(LogisticRegression(),param_grid,refit=True,verbose=3,n_jobs=1,scoring='f1_weighted')
grid_model.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END ............penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ............penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ............penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ............penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ............penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END ......penalty=l1, solver=liblinear;, score=0.836 total time=   0.0s
# [CV 2/5] END ......penalty=l1, solver=liblinear;, score=0.802 total time=   0.0s
# [CV 3/5] END ......penalty=l1, solver=liblinear;, score=0.645 total time=   0.0s
# [CV 4/5] END ......penalty=l1, solver=liblinear;, score=0.928 total time=   0.0s
# [CV 5/5] END ......penalty=l1, solver=liblinear;, score=0.909 total time=   0.0s
# [CV 1/5] END ........penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# ...

# %%
result=grid_model.cv_results_

# %%
grid_pred=grid_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_pred)
print(cm)
# Out:
# [[74  5]
#  [ 8 33]]

# %%
from sklearn.metrics import classification_report
classy=classification_report(y_test,grid_pred)
print(classy)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        79
#            1       0.87      0.80      0.84        41
#
#     accuracy                           0.89       120
#    macro avg       0.89      0.87      0.88       120
# weighted avg       0.89      0.89      0.89       120

# %%
from sklearn.metrics import roc_auc_score # r-receiver, o-operating, c- curve | a-area, u- under, c-curve
roc_auc_score(y_test,grid_model.predict_proba(x_test)[:,1])
# Out:
# np.float64(0.9493670886075949)

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001085      0.000363         0.000000        0.000000
# 1        0.002068      0.000544         0.004399        0.001038
# 2        0.001238      0.000345         0.000000        0.000000
# 3        0.000636      0.000120         0.000000        0.000000
# 4        0.000638      0.000167         0.000000        0.000000
# 5        0.001567      0.000222         0.002387        0.000137
# 6        0.005361      0.005528         0.002949        0.000178
# 7        0.001414      0.000086         0.002893        0.000163
# 8        0.005252      0.001003         0.013120        0.018060
# 9        0.012363      0.011713         0.004371        0.000430
# 10       0.002586      0.000521         0.003883        0.000865
# 11       0.002262      0.000237         0.003683        0.000231
# 12       0.000898      0.000074         0.000000        0.000000
# ...
