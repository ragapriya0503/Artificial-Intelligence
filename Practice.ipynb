# %%
print("hi")
# Out:
# hi

# %%
print("hello")
# Out:
# hello

# %%
week=int(input("Enter the week"))
if(week==2):
    print("It's Monday")
elif(week==3):
    print("It's Tuesday")
else:
    print("It's another day")
# Out:
# Enter the week 5
# It's another day

# %%
for x in range(6):
      print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
